# %% [markdown]
# Складіть рівняння параболи що проходить через задані три точки (1, 12), (3, 54), (-1, 2). Необхідно знайти коефіцієнти рівняння a,b,c
#
# y = a * x ^ 2 + b * x + c

# %% [markdown]
# Запишемо систему лінійних рівнянь
#
# 12 = 1 ^ 2 * a + 1 * b + c
#
# 54 = 3 ^ 2 * a + 3 * b + c
#
# 2 = 1 ^ 2 * a - 1 * b + c
#
# Складемо матрицю і визначемо коефіцієнти a, b, c

# %%
import numpy as np
A = np.array([[1, 1, 1], [9, 3, 1], [1, -1, 1]])
B = np.array([12, 54, 2])

# %%
x = np.linalg.solve(A, B)

# %% [markdown]
# коефіцієнти a, b, c

# %%
x
# Out:
# array([4., 5., 3.])

# %% [markdown]
# коефіцієнти a = 4, b = 5, c = 3
